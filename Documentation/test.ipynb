# %% [markdown]
# # Quoi mettre dans la documentation
#
# ## Principe du projet
#
# ## Objectifs
#
# ## Matériel utilisé
# ### avec liens
#
# ## Scripts et librairies requises
#
# ## Interfaces moteur et puissance mètre
#
# ## GUI
